# %% [markdown]
# # Next-Frame Video Prediction with Convolutional LSTMs
#
# **Author:** [Amogh Joshi](https://github.com/amogh7joshi)<br>
# **Date created:** 2021/06/02<br>
# **Last modified:** 2021/06/05<br>
# **Description:** How to build and train a convolutional LSTM model for next-frame video prediction.

# %% [markdown]
# ## Introduction
#
# The
# [Convolutional LSTM](https://papers.nips.cc/paper/2015/file/07563a3fe3bbe7e3ba84431ad9d055af-Paper.pdf)
# architectures bring together time series processing and computer vision by
# introducing a convolutional recurrent cell in a LSTM layer. In this example, we will explore the
# Convolutional LSTM model in an application to next-frame prediction, the process
# of predicting what video frames come next given a series of past frames.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import io
import imageio
from IPython.display import Image, display
from ipywidgets import widgets, Layout, HBox

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# 2022-05-27 00:24:28.099933: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-27 00:24:28.122252: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:28.149125: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:28.149281: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:28.545018: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:28.545156: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:28.545263: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:28.545359: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /device:GPU:0 with 4939 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:2b:00.0, compute capability: 8.6
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 7731188292097180025
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 5179637760
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 12867784973590187184
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:2b:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %% [markdown]
# ## Dataset Construction
#
# For this example, we will be using the
# [Moving MNIST](http://www.cs.toronto.edu/~nitish/unsupervised_video/)
# dataset.
#
# We will download the dataset and then construct and
# preprocess training and validation sets.
#
# For next-frame prediction, our model will be using a previous frame,
# which we'll call `f_n`, to predict a new frame, called `f_(n + 1)`.
# To allow the model to create these predictions, we'll need to process
# the data such that we have "shifted" inputs and outputs, where the
# input data is frame `x_n`, being used to predict frame `y_(n + 1)`.

# %%
# # Download and load the dataset.
# fpath = keras.utils.get_file(
#     "moving_mnist.npy",
#     "http://www.cs.toronto.edu/~nitish/unsupervised_video/mnist_test_seq.npy",
# )
# dataset = np.load(fpath)

# # Swap the axes representing the number of frames and number of data samples.
# dataset = np.swapaxes(dataset, 0, 1)
# # We'll pick out 1000 of the 10000 total examples and use those.
# dataset = dataset[:1000, ...]
# # Add a channel dimension since the images are grayscale.
# dataset = np.expand_dims(dataset, axis=-1)

# # Split into train and validation sets using indexing to optimize memory.
# indexes = np.arange(dataset.shape[0])
# np.random.shuffle(indexes)
# train_index = indexes[: int(0.9 * dataset.shape[0])]
# val_index = indexes[int(0.9 * dataset.shape[0]) :]
# train_dataset = dataset[train_index]
# val_dataset = dataset[val_index]

# # Normalize the data to the 0-1 range.
# train_dataset = train_dataset / 255
# val_dataset = val_dataset / 255

# dataset.shape

# %%
# import sys
# log_path = 'log.txt'
# sys.stdout = open(log_path, "w")

import h5py
h5 = h5py.File('./reformattedData_20220523/ConvLSTM_all_cases_80x80_per1000_previousPhi_zoom_withTipsTheta_20_compressed.hdf5', mode='r')
dataset = h5.get('phi')

# Split into train and validation sets using indexing to optimize memory.
# indexes = np.arange(dataset.shape[0])
# np.random.shuffle(indexes)
# train_index = indexes[: int(0.9 * dataset.shape[0])]
# val_index = indexes[int(0.9 * dataset.shape[0]) :]
train_index = np.arange(45)
val_index = np.arange(16)+45
train_dataset = dataset[train_index]
val_dataset = dataset[val_index]

# Normalize the data to the 0-1 range.
train_dataset = train_dataset
val_dataset = val_dataset

dataset.shape
# Out:
# (64, 20, 80, 80, 2)

# %%
# We'll define a helper function to shift the frames, where
# `x` is frames 0 to n - 1, and `y` is frames 1 to n.
def create_shifted_frames(data):
    x = data[:, 0 : data.shape[1] - 1, :, :]
    y = data[:, 1 : data.shape[1], :, :]
    return x, y

def create_shifted_frames_one2many(data):
    x = data[:, 0:1 , :, :]
    y = data[:, 1 : data.shape[1], :, :]
    return x, y

# Apply the processing function to the datasets.
x_train, y_train = create_shifted_frames(train_dataset)
x_val, y_val = create_shifted_frames(val_dataset)
# x_train, y_train = create_shifted_frames_one2many(train_dataset)
# x_val, y_val = create_shifted_frames_one2many(val_dataset)

# Inspect the dataset.
print("Training Dataset Shapes: " + str(x_train.shape) + ", " + str(y_train.shape))
print("Validation Dataset Shapes: " + str(x_val.shape) + ", " + str(y_val.shape))
# Out:
# Training Dataset Shapes: (45, 19, 80, 80, 2), (45, 19, 80, 80, 2)
# Validation Dataset Shapes: (16, 19, 80, 80, 2), (16, 19, 80, 80, 2)

# %% [markdown]
# ## Data Visualization
#
# Our data consists of sequences of frames, each of which
# are used to predict the upcoming frame. Let's take a look
# at some of these sequential frames.

# %%
# Construct a figure on which we will visualize the images.
fig, axes = plt.subplots(4, 5, figsize=(14, 12))

# Plot each of the sequential images for one random data example.
data_choice = np.random.choice(range(len(train_dataset)), size=1)[0]
for idx, ax in enumerate(axes.flat):
    ax.imshow(np.squeeze(train_dataset[data_choice][idx][:,:,0]), cmap="gray")
    ax.set_title(f"Frame {idx + 1}")
    ax.axis("off")

# Print information and display the figure.
print(f"Displaying frames for example {data_choice}.")
plt.show()
# Out:
# Displaying frames for example 35.

# %% [markdown]
# ## Model Construction
#
# To build a Convolutional LSTM model, we will use the
# `ConvLSTM2D` layer, which will accept inputs of shape
# `(batch_size, num_frames, width, height, channels)`, and return
# a prediction movie of the same shape.

# %%
# # Construct the input layer with no definite frame size.
# inp = layers.Input(shape=(None, *x_train.shape[2:]))

# x0 = layers.ConvLSTM2D(
#     filters=64,
#     kernel_size=(5, 5),
#     strides = (2, 2),
#     padding="valid",
#     return_sequences=True,
#     activation="relu",
# )(inp)
# x1 = layers.BatchNormalization()(x0)
# x2 = layers.ConvLSTM2D(
#     filters=128,
#     kernel_size=(5, 5),
#     strides = (2, 2),
#     padding="valid",
#     return_sequences=True,
#     activation="relu",
# )(x1)
# x3 = layers.BatchNormalization()(x2)
# x4 = layers.TimeDistributed(layers.Conv2DTranspose(
#     filters=64,
#     kernel_size=(6, 6),
#     strides = (2, 2),
#     padding="valid",
#     activation="relu",
# ))(x3)
# x5 = layers.BatchNormalization()(x4)
# x6 = layers.TimeDistributed(layers.Conv2DTranspose(
#     filters=1,
#     kernel_size=(6, 6),
#     strides = (2, 2),
#     padding="valid",
#     activation="relu",
# ))(x5)

# x6.shape

# %%
# Construct the input layer with no definite frame size.
inp = layers.Input(shape=(None, *x_train.shape[2:]))

# We will construct 3 `ConvLSTM2D` layers with batch normalization,
# followed by a `Conv3D` layer for the spatiotemporal outputs.
x0 = layers.TimeDistributed(layers.Conv2D(
    filters=64,
    kernel_size=(5, 5),
    strides = (2, 2),
    padding="valid",
    activation="relu",
))(inp)
x1 = layers.TimeDistributed(layers.Conv2D(
    filters=128,
    kernel_size=(5, 5),
    strides = (2, 2),
    padding="valid",
    activation="relu",
))(x0)
x2 = layers.ConvLSTM2D(
    filters=128,
    kernel_size=(5, 5),
    padding="same",
    return_sequences=True,
    activation="relu",
)(x1)
x3 = layers.Concatenate(axis=4)([x1,x2])
x4 = layers.TimeDistributed(layers.Conv2DTranspose(
    filters=64,
    kernel_size=(6, 6),
    strides = (2, 2),
    padding="valid",
    activation="relu",
))(x3)
x5 = layers.Concatenate(axis=4)([x0,x4])
x6 = layers.TimeDistributed(layers.Conv2DTranspose(
    filters=1,
    kernel_size=(6, 6),
    strides = (2, 2),
    padding="valid",
    activation="relu",
))(x5)
# Out:
# 2022-05-27 00:24:29.663725: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:29.663895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:29.663996: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:29.664234: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:29.664344: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:29.664443: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:29.664582: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:29.664686: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-27 00:24:29.664764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4939 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:2b:00.0, compute capability: 8.6

# %%
# Next, we will build the complete model and compile it.
model = keras.models.Model(inp, x6)
model.compile(
    loss=keras.losses.binary_crossentropy, optimizer=keras.optimizers.Adam(),
    # loss=keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error"), optimizer=keras.optimizers.Adam(),
)
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, 80, 8  0           []
#                                 0, 2)]
#
#  time_distributed (TimeDistribu  (None, None, 38, 38  3264       ['input_1[0][0]']
#  ted)                           , 64)
#
#  time_distributed_1 (TimeDistri  (None, None, 17, 17  204928     ['time_distributed[0][0]']
#  buted)                         , 128)
#
#  conv_lstm2d (ConvLSTM2D)       (None, None, 17, 17  3277312     ['time_distributed_1[0][0]']
#                                 , 128)
#
#  concatenate (Concatenate)      (None, None, 17, 17  0           ['time_distributed_1[0][0]',
#                                 , 256)                            'conv_lstm2d[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, None, 38, 38  589888     ['concatenate[0][0]']
#  buted)                         , 64)
#
#  concatenate_1 (Concatenate)    (None, None, 38, 38  0           ['time_distributed[0][0]',
#                                 , 128)                            'time_distributed_2[0][0]']
#
#  time_distributed_3 (TimeDistri  (None, None, 80, 80  4609       ['concatenate_1[0][0]']
#  buted)                         , 1)
#
# ==================================================================================================
# Total params: 4,080,001
# Trainable params: 4,080,001
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Model Training
#
# With our model and data constructed, we can now train the model.

# %%
# Define some callbacks to improve training.
# early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10)
# reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5)
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=20)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=10)

# Define modifiable training hyperparameters.
epochs = 150
batch_size = 1

# with tf.device('/device:CPU:0'):
with tf.device('/device:GPU:0'):

    # Fit the model to the training data.
    model.fit(
        x_train,
        y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(x_val, y_val),
        # callbacks=[early_stopping, reduce_lr],
    )
# Out:
# Epoch 1/150
# 2022-05-27 00:24:31.109262: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:828] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'Func/gradient_tape/model/conv_lstm2d/while/model/conv_lstm2d/while_grad/body/_189/input/_551' -> 'gradient_tape/model/conv_lstm2d/while/model/conv_lstm2d/while_grad/body/_189/gradient_tape/model/conv_lstm2d/while/gradients/AddN', 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/clip_by_value' -> 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/mul_3', 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/mul_2' -> 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/add_5', 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/convolution_6' -> 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/add_4', 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/clip_by_value_2' -> 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/mul_5'}.
# 2022-05-27 00:24:31.857700: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8303
# 2022-05-27 00:24:32.605754: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 45/45 [==============================] - ETA: 0s - loss: 0.1308
# 2022-05-27 00:24:35.970131: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:828] layout failed: INVALID_ARGUMENT: MutableGraphView::SortTopologically error: detected edge(s) creating cycle(s) {'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/Relu_1' -> 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/mul_5', 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/mul_2' -> 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/add_5', 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/convolution_7' -> 'model/conv_lstm2d/while/body/_1/model/conv_lstm2d/while/add_6'}.
# 45/45 [==============================] - 6s 78ms/step - loss: 0.1308 - val_loss: 0.0934
# Epoch 2/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0921 - val_loss: 0.0880
# Epoch 3/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0884 - val_loss: 0.0853
# Epoch 4/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0865 - val_loss: 0.0840
# Epoch 5/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0880 - val_loss: 0.0884
# Epoch 6/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0874 - val_loss: 0.0840
# Epoch 7/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0853 - val_loss: 0.0829
# Epoch 8/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0849 - val_loss: 0.0826
# Epoch 9/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0842 - val_loss: 0.0828
# Epoch 10/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0842 - val_loss: 0.0828
# Epoch 11/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0846 - val_loss: 0.0847
# Epoch 12/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0848 - val_loss: 0.0821
# Epoch 13/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0837 - val_loss: 0.0817
# Epoch 14/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0836 - val_loss: 0.0831
# Epoch 15/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0844 - val_loss: 0.0826
# Epoch 16/150
# 45/45 [==============================] - 3s 77ms/step - loss: 0.0836 - val_loss: 0.0815
# Epoch 17/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0827 - val_loss: 0.0808
# Epoch 18/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0827 - val_loss: 0.0813
# Epoch 19/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0833 - val_loss: 0.0812
# Epoch 20/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0832 - val_loss: 0.0814
# Epoch 21/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0837 - val_loss: 0.0993
# Epoch 22/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0883 - val_loss: 0.0827
# Epoch 23/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0840 - val_loss: 0.0824
# Epoch 24/150
# 45/45 [==============================] - 3s 77ms/step - loss: 0.0834 - val_loss: 0.0812
# Epoch 25/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0827 - val_loss: 0.0808
# Epoch 26/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0825 - val_loss: 0.0808
# Epoch 27/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0839 - val_loss: 0.0819
# Epoch 28/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0829 - val_loss: 0.0809
# Epoch 29/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0822 - val_loss: 0.0804
# Epoch 30/150
# 45/45 [==============================] - 3s 77ms/step - loss: 0.0822 - val_loss: 0.0805
# Epoch 31/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0822 - val_loss: 0.0815
# Epoch 32/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0820 - val_loss: 0.0800
# Epoch 33/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0821 - val_loss: 0.0810
# Epoch 34/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0818 - val_loss: 0.0803
# Epoch 35/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0826 - val_loss: 0.0841
# Epoch 36/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0843 - val_loss: 0.0823
# Epoch 37/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0828 - val_loss: 0.0811
# Epoch 38/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0859 - val_loss: 0.0843
# Epoch 39/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0859 - val_loss: 0.0837
# Epoch 40/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0843 - val_loss: 0.0828
# Epoch 41/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0835 - val_loss: 0.0815
# Epoch 42/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0833 - val_loss: 0.0815
# Epoch 43/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0825 - val_loss: 0.0806
# Epoch 44/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0822 - val_loss: 0.0807
# Epoch 45/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0826 - val_loss: 0.0810
# Epoch 46/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0823 - val_loss: 0.0811
# Epoch 47/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0845 - val_loss: 0.0826
# Epoch 48/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0828 - val_loss: 0.0821
# Epoch 49/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0841 - val_loss: 0.0817
# Epoch 50/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0827 - val_loss: 0.0806
# Epoch 51/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0824 - val_loss: 0.0808
# Epoch 52/150
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0817 - val_loss: 0.0800
# Epoch 53/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0821 - val_loss: 0.0810
# Epoch 54/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0829 - val_loss: 0.0812
# Epoch 55/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0821 - val_loss: 0.0806
# Epoch 56/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0818 - val_loss: 0.0801
# Epoch 57/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0813 - val_loss: 0.0801
# Epoch 58/150
# 45/45 [==============================] - 3s 77ms/step - loss: 0.0817 - val_loss: 0.0806
# Epoch 59/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0813 - val_loss: 0.0799
# Epoch 60/150
# 45/45 [==============================] - 3s 77ms/step - loss: 0.0811 - val_loss: 0.0802
# Epoch 61/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0812 - val_loss: 0.0797
# Epoch 62/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0809 - val_loss: 0.0796
# Epoch 63/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0809 - val_loss: 0.0797
# Epoch 64/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0809 - val_loss: 0.0797
# Epoch 65/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0816 - val_loss: 0.0805
# Epoch 66/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0810 - val_loss: 0.0796
# Epoch 67/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0818 - val_loss: 0.0802
# Epoch 68/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0809 - val_loss: 0.0797
# Epoch 69/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0832 - val_loss: 0.0818
# Epoch 70/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0818 - val_loss: 0.0799
# Epoch 71/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0809 - val_loss: 0.0797
# Epoch 72/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0869 - val_loss: 0.0838
# Epoch 73/150
# 45/45 [==============================] - 3s 67ms/step - loss: 0.0838 - val_loss: 0.0814
# Epoch 74/150
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0826 - val_loss: 0.0809
# Epoch 75/150
# 45/45 [==============================] - 3s 71ms/step - loss: 0.0818 - val_loss: 0.0805
# Epoch 76/150
# 45/45 [==============================] - 3s 68ms/step - loss: 0.0819 - val_loss: 0.0805
# Epoch 77/150
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0814 - val_loss: 0.0802
# Epoch 78/150
# 45/45 [==============================] - 3s 71ms/step - loss: 0.0811 - val_loss: 0.0800
# Epoch 79/150
# 45/45 [==============================] - 3s 67ms/step - loss: 0.0815 - val_loss: 0.0804
# Epoch 80/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0812 - val_loss: 0.0800
# Epoch 81/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0811 - val_loss: 0.0803
# Epoch 82/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0810 - val_loss: 0.0798
# Epoch 83/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0809 - val_loss: 0.0802
# Epoch 84/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0816 - val_loss: 0.0800
# Epoch 85/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0808 - val_loss: 0.0798
# Epoch 86/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0807 - val_loss: 0.0796
# Epoch 87/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0805 - val_loss: 0.0797
# Epoch 88/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0809 - val_loss: 0.0807
# Epoch 89/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0808 - val_loss: 0.0798
# Epoch 90/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0806 - val_loss: 0.0800
# Epoch 91/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0810 - val_loss: 0.0820
# Epoch 92/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0817 - val_loss: 0.0801
# Epoch 93/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0807 - val_loss: 0.0798
# Epoch 94/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0807 - val_loss: 0.0799
# Epoch 95/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0804 - val_loss: 0.0799
# Epoch 96/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0802 - val_loss: 0.0796
# Epoch 97/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0800 - val_loss: 0.0795
# Epoch 98/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0799 - val_loss: 0.0794
# Epoch 99/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0816 - val_loss: 0.0808
# Epoch 100/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0807 - val_loss: 0.0829
# Epoch 101/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0818 - val_loss: 0.0801
# Epoch 102/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0818 - val_loss: 0.0810
# Epoch 103/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0816 - val_loss: 0.0806
# Epoch 104/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0815 - val_loss: 0.0805
# Epoch 105/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0809 - val_loss: 0.0800
# Epoch 106/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0807 - val_loss: 0.0802
# Epoch 107/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0805 - val_loss: 0.0805
# Epoch 108/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0812 - val_loss: 0.0809
# Epoch 109/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0808 - val_loss: 0.0800
# Epoch 110/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0804 - val_loss: 0.0797
# Epoch 111/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0806 - val_loss: 0.0949
# Epoch 112/150
# 45/45 [==============================] - 3s 71ms/step - loss: 0.0871 - val_loss: 0.0840
# Epoch 113/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0835 - val_loss: 0.0809
# Epoch 114/150
# 45/45 [==============================] - 3s 71ms/step - loss: 0.0821 - val_loss: 0.0811
# Epoch 115/150
# 45/45 [==============================] - 3s 71ms/step - loss: 0.0823 - val_loss: 0.0811
# Epoch 116/150
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0818 - val_loss: 0.0805
# Epoch 117/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0814 - val_loss: 0.0807
# Epoch 118/150
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0812 - val_loss: 0.0803
# Epoch 119/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0807 - val_loss: 0.0801
# Epoch 120/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0810 - val_loss: 0.0807
# Epoch 121/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0809 - val_loss: 0.0803
# Epoch 122/150
# 45/45 [==============================] - 3s 77ms/step - loss: 0.0808 - val_loss: 0.0805
# Epoch 123/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0809 - val_loss: 0.0801
# Epoch 124/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0816 - val_loss: 0.0824
# Epoch 125/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0819 - val_loss: 0.0803
# Epoch 126/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0809 - val_loss: 0.0803
# Epoch 127/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0807 - val_loss: 0.0809
# Epoch 128/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0809 - val_loss: 0.0805
# Epoch 129/150
# 45/45 [==============================] - 3s 77ms/step - loss: 0.0806 - val_loss: 0.0803
# Epoch 130/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0803 - val_loss: 0.0802
# Epoch 131/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0801 - val_loss: 0.0799
# Epoch 132/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0800 - val_loss: 0.0800
# Epoch 133/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0803 - val_loss: 0.0809
# Epoch 134/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0804 - val_loss: 0.0800
# Epoch 135/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0800 - val_loss: 0.0800
# Epoch 136/150
# 45/45 [==============================] - 3s 71ms/step - loss: 0.0799 - val_loss: 0.0799
# Epoch 137/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0800 - val_loss: 0.0803
# Epoch 138/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0799 - val_loss: 0.0800
# Epoch 139/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0799 - val_loss: 0.0805
# Epoch 140/150
# 45/45 [==============================] - 3s 74ms/step - loss: 0.0798 - val_loss: 0.0799
# Epoch 141/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0796 - val_loss: 0.0799
# Epoch 142/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0797 - val_loss: 0.0801
# Epoch 143/150
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0795 - val_loss: 0.0799
# Epoch 144/150
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0794 - val_loss: 0.0800
# Epoch 145/150
# 45/45 [==============================] - 3s 77ms/step - loss: 0.0795 - val_loss: 0.0801
# Epoch 146/150
# 45/45 [==============================] - 3s 71ms/step - loss: 0.0793 - val_loss: 0.0799
# Epoch 147/150
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0795 - val_loss: 0.0801
# Epoch 148/150
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0798 - val_loss: 0.0808
# Epoch 149/150
# 45/45 [==============================] - 3s 75ms/step - loss: 0.0825 - val_loss: 0.0829
# Epoch 150/150
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0828 - val_loss: 0.0814

# %%
model.save('./tmp/model_crossBin350_1')
# loaded_model = tf.keras.models.load_model('/tmp/model')
# Out:
# 2022-05-27 00:32:49.218946: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ./tmp/model_crossBin350_1/assets

# %%
# # Select a random example from the validation dataset.
# example = val_dataset[np.random.choice(range(len(val_dataset)), size=1)[0]]

# # Pick the first/last ten frames from the example.
# frames = example[:10, ...]

# test1 = frames[5,:,:,0]
# test2 = frames[5,:,:,1]
# import matplotlib.pyplot as plt
# plt.subplot(1,2,1)
# plt.imshow(test1)
# plt.subplot(1,2,2)
# plt.imshow(test2)

# %%
# import matlab.engine

# eng = matlab.engine.start_matlab()
# phi = matlab.double(test1.tolist())
# iter = 20000
# tips_mat = eng.generate_tips_for_python(phi,iter)
# tips = tips_mat.clone() 

# plt.subplot(1,2,1)
# plt.imshow(phi)
# plt.subplot(1,2,2)
# plt.imshow(tips_mat)

# %% [markdown]
# ## Frame Prediction Visualizations
#
# With our model now constructed and trained, we can generate
# some example frame predictions based on a new video.
#
# We'll pick a random example from the validation set and
# then choose the first ten frames from them. From there, we can
# allow the model to predict 10 new frames, which we can compare
# to the ground truth frame predictions.

# %%
# Select a random example from the validation dataset.
example = val_dataset[np.random.choice(range(len(val_dataset)), size=1)[0]]

# Pick the first/last ten frames from the example.
frames = example[:10, ...]
original_frames = example[10:, ...]

# Predict a new set of 10 frames.
for i in range(10):
    # Extract the model's prediction and post-process it.
    new_prediction = model.predict(np.expand_dims(frames, axis=0))
    new_prediction = np.squeeze(new_prediction, axis=0)
    predicted_frame = np.expand_dims(new_prediction[-1, ...], axis=0)

    pred_set = np.concatenate((predicted_frame[0,:,:,:], np.expand_dims(original_frames[i,:,:,1],2)), axis=2)

    # plt.imshow(predicted_frame[0,:,:,0])
    # plt.show()
    # Extend the set of prediction frames.
    # frames = np.concatenate((frames, predicted_frame), axis=0)
    frames = np.concatenate((frames, np.expand_dims(pred_set,0)), axis=0)
    # print(frames.shape)
# Construct a figure for the original and new frames.
fig, axes = plt.subplots(2, 10, figsize=(20, 4))

# Plot the original frames.
for idx, ax in enumerate(axes[0]):
    ax.imshow(np.squeeze(original_frames[idx,:,:,0]), cmap="gray")
    ax.set_title(f"Frame {idx + 11}")
    ax.axis("off")

# Plot the new frames.
new_frames = frames[10:, ...]
for idx, ax in enumerate(axes[1]):
    ax.imshow(np.squeeze(new_frames[idx,:,:,0]), cmap="gray")
    ax.set_title(f"Frame {idx + 11}")
    ax.axis("off")

# Display the figure.
plt.show()

plt.savefig('convLSTMresults.png')

# %% [markdown]
# ## Predicted Videos
#
# Finally, we'll pick a few examples from the validation set
# and construct some GIFs with them to see the model's
# predicted videos.
#
# You can use the trained model hosted on [Hugging Face Hub](https://huggingface.co/keras-io/conv-lstm) and try the demo on [Hugging Face Spaces](https://huggingface.co/spaces/keras-io/conv-lstm).

# %%
for i in range(20):
    plt.figure(figsize=(16, 4), dpi=60)
    plt.subplot(1,4,1)
    plt.imshow(np.squeeze(frames[i,:,:,0]), cmap="jet")
    plt.subplot(1,4,2)
    plt.imshow(np.squeeze(frames[i,:,:,1]), cmap="jet")
    plt.subplot(1,4,3)
    plt.imshow(np.squeeze(example[i,:,:,0]), cmap="jet")
    plt.subplot(1,4,4)
    plt.imshow(np.squeeze(example[i,:,:,1]), cmap="jet")
    plt.title(i)
    plt.show()

# %%
plt.subplot(1,2,1)
plt.imshow(np.squeeze(frames[9,:,:,0]), cmap="jet")
plt.title(9)
plt.subplot(1,2,2)
plt.imshow(np.squeeze(frames[20,:,:,0]), cmap="jet")
plt.title(21)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/kuanrenqian/Documents/Data_generation_for_conv2DLSTM/conv_lstm_1.ipynb Cell 25' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/home/kuanrenqian/Documents/Data_generation_for_conv2DLSTM/conv_lstm_1.ipynb#ch0000024?line=2'>3</a> plt.title(9)
#       <a href='vscode-notebook-cell:/home/kuanrenqian/Documents/Data_generation_for_conv2DLSTM/conv_lstm_1.ipynb#ch0000024?line=3'>4</a> plt.subplot(1,2,2)
# ----> <a href='vscode-notebook-cell:/home/kuanrenqian/Documents/Data_generation_for_conv2DLSTM/conv_lstm_1.ipynb#ch0000024?line=4'>5</a> plt.imshow(np.squeeze(frames[20,:,:,0]), cmap="jet")
#       <a href='vscode-notebook-cell:/home/kuanrenqian/Documents/Data_generation_for_conv2DLSTM/conv_lstm_1.ipynb#ch0000024?line=5'>6</a> plt.title(21)
#       <a href='vscode-notebook-cell:/home/kuanrenqian/Documents/Data_generation_for_conv2DLSTM/conv_lstm_1.ipynb#ch0000024?line=6'>7</a> plt.show()
#
# IndexError: index 20 is out of bounds for axis 0 with size 20

# %%
# Select a few random examples from the dataset.
examples = val_dataset[np.random.choice(range(len(val_dataset)), size=5)]

# Iterate over the examples and predict the frames.
predicted_videos = []
for example in examples:
    # Pick the first/last ten frames from the example.
    frames = example[:10, ...]
    original_frames = example[10:, ...]
    new_predictions = np.zeros(shape=(10, *frames[0].shape))

    # Predict a new set of 10 frames.
    for i in range(10):
        # Extract the model's prediction and post-process it.
        frames = example[: 10 + i + 1, ...]
        new_prediction = model.predict(np.expand_dims(frames, axis=0))
        new_prediction = np.squeeze(new_prediction, axis=0)
        predicted_frame = np.expand_dims(new_prediction[-1, ...], axis=0)

        example[: 10 + i + 2, ...] = predicted_frame

        # Extend the set of prediction frames.
        new_predictions[i] = predicted_frame

    # Create and save GIFs for each of the ground truth/prediction images.
    for frame_set in [original_frames, new_predictions]:
        # Construct a GIF from the selected video frames.
        current_frames = np.squeeze(frame_set)
        current_frames = current_frames[..., np.newaxis] * np.ones(3)
        current_frames = (current_frames * 255).astype(np.uint8)
        current_frames = list(current_frames)

        # Construct a GIF from the frames.
        with io.BytesIO() as gif:
            imageio.mimsave(gif, current_frames, "GIF", fps=5)
            predicted_videos.append(gif.getvalue())

# Display the videos.
print(" Truth\tPrediction")
for i in range(0, len(predicted_videos), 2):
    # Construct and display an `HBox` with the ground truth and prediction.
    box = HBox(
        [
            widgets.Image(value=predicted_videos[i]),
            widgets.Image(value=predicted_videos[i + 1]),
        ]
    )
    display(box)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/kuanrenqian/Documents/Data_generation_for_conv2DLSTM/conv_lstm.ipynb Cell 26' in <cell line: 6>()
#      <a href='vscode-notebook-cell:/home/kuanrenqian/Documents/Data_generation_for_conv2DLSTM/conv_lstm.ipynb#ch0000019?line=32'>33</a>         # Construct a GIF from the frames.
#      <a href='vscode-notebook-cell:/home/kuanrenqian/Documents/Data_generation_for_conv2DLSTM/conv_lstm.ipynb#ch0000019?line=33'>34</a>         with io.BytesIO() as gif:
# ---> <a href='vscode-notebook-cell:/home/kuanrenqian/Documents/Data_generation_for_conv2DLSTM/conv_lstm.ipynb#ch0000019?line=34'>35</a>             imageio.mimsave(gif, current_frames, "GIF", fps=5)
#      <a href='vscode-notebook-cell:/home/kuanrenqian/Documents/Data_generation_for_conv2DLSTM/conv_lstm.ipynb#ch0000019?line=35'>36</a>             predicted_videos.append(gif.getvalue())
#      <a href='vscode-notebook-cell:/home/kuanrenqian/Documents/Data_generation_for_conv2DLSTM/conv_lstm.ipynb#ch0000019?line=37'>38</a> # Display the videos.
#
# File ~/anaconda3/lib/python3.9/site-packages/imageio/core/functions.py:415, in mimwrite(uri, ims, format, **kwargs)
#     <a href='file:///home/kuanrenqian/anaconda3/lib/python3.9/site-packages/imageio/core/functions.py?line=412'>413</a>     pass
#     <a href='file:///home/kuanrenqian/anaconda3/lib/python3.9/site-packages/imageio/core/functions.py?line=413'>414</a> else:
# --> <a href='file:///home/kuanrenqian/anaconda3/lib/python3.9/site-packages/imageio/core/functions.py?line=414'>415</a>     raise ValueError("Image must be 2D " "(grayscale, RGB, or RGBA).")
#     <a href='file:///home/kuanrenqian/anaconda3/lib/python3.9/site-packages/imageio/core/functions.py?line=416'>417</a> # Add image
#     <a href='file:///home/kuanrenqian/anaconda3/lib/python3.9/site-packages/imageio/core/functions.py?line=417'>418</a> writer.append_data(im)
#
# ValueError: Image must be 2D (grayscale, RGB, or RGBA).
